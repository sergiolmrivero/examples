# %% [markdown]
# # Simple Economy Model
#
# Agent-based simulation of a minimal macroeconomic model with three agent types:
# - **Household** – supplies labour, demands consumption goods, pays income tax.
# - **CGFirm** – hires labour, produces and sells goods, pays profit tax and distributes dividends.
# - **Government** – collects taxes, pays unemployment benefits, tracks macro aggregates.

# %%
import os
import math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

sns.set_theme(style="whitegrid")
pd.options.mode.chained_assignment = None

input_dir  = Path("runs")
output_dir = Path("results")
output_dir.mkdir(exist_ok=True)
import EcoSimpy

# %% [markdown]
# ## Run the Simulation

# %%
def main():
    print("Current directory:", os.getcwd())

    config_json_file = "config.json"
    app_dir = os.getcwd()

    sim = EcoSimpy.Simulation(app_dir,
                              config_json_file,
                              clean_run=True)
    sim.execute_simulation()


if __name__ == "__main__":
    main()
else:
    main()
# Out:
# Current directory: /home/rivero/Dropbox/Workspace_Current/Projects/Apps/EcoSim/EcoSimpy_dev/examples/simple_economy
# Simulation config file path: /home/rivero/Dropbox/Workspace_Current/Projects/Apps/EcoSim/EcoSimpy_dev/examples/simple_economy/config.json (simulation.py)
# Active scenario set to Scenario1 (simulation.py)
# Scenario: Scenario1 Run nr.: 0: 100%|██████████| 60/60 [00:00<00:00, 45059.67it/s]
# Scenario: Scenario1 Run nr.: 1: 100%|██████████| 60/60 [00:00<00:00, 54471.48it/s]
# Scenario: Scenario1 Run nr.: 2: 100%|██████████| 60/60 [00:00<00:00, 66806.01it/s]
# Observer data saved to simple_economy_Household_obs1_2026-05-06T17_14_.csv (simulation.py)
